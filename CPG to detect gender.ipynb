# %%
 # Clonning the git repo
# !git clone https://github.com/Whizz-Technologies/CPG.git
# Out:
# Cloning into 'CPG'...
# remote: Enumerating objects: 519, done.
# remote: Counting objects: 100% (193/193), done.
# remote: Compressing objects: 100% (84/84), done.
# remote: Total 519 (delta 114), reused 175 (delta 105), pack-reused 326
# Receiving objects: 100% (519/519), 12.32 MiB | 13.83 MiB/s, done.
# Resolving deltas: 100% (304/304), done.

# %%
# Installing the gdown lib 
# !pip install gdown
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Changing the directory
# %cd CPG
# Making the face_data directory
# %mkdir face_data
# Out:
# /content/CPG

# %%
# Downloading the face_weight.pth
# !gdown --id 1P3KiJGdanBbTpSFeLtbQCXIyoYrW8LtN
# Out:
# /usr/local/lib/python3.9/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1P3KiJGdanBbTpSFeLtbQCXIyoYrW8LtN
# To: /content/CPG/face_weight.pth
# 100% 108M/108M [00:02<00:00, 36.1MB/s]

# %%
# Downloading the lfw_pairs.txt
# !gdown --id 1wuKxHrDXebWicDxqt6FpBMhMbdN6wEDf
# Out:
# /usr/local/lib/python3.9/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1wuKxHrDXebWicDxqt6FpBMhMbdN6wEDf
# To: /content/CPG/lfw_pairs.txt
# 100% 155k/155k [00:00<00:00, 110MB/s]

# %%
# Downloading the face_datasets.zip
# !gdown --id 1F2jx7k15EWA1P64Bp462ovB4zHb50tz_
# Out:
# /usr/local/lib/python3.9/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1F2jx7k15EWA1P64Bp462ovB4zHb50tz_
# To: /content/CPG/face_datasets.zip
# 100% 3.97G/3.97G [01:08<00:00, 58.0MB/s]

# %%
# Unzipping the face_datasets.zip
# !unzip face_datasets.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: gender/train/0/78nm1172478_rm2198787840_1979-11-25_2014.jpg
#   inflating: gender/train/0/45nm0000245_rm2826487808_1951-7-21_1978.jpg
#   inflating: gender/train/0/4422998644_1982-06-06_2014.jpg
#   inflating: gender/train/0/50nm1504650_rm1457039872_1977-9-23_2012.jpg
#   inflating: gender/train/0/33nm0001133_rm3041957888_1938-7-9_2007.jpg
#   inflating: gender/train/0/78nm0004778_rm2769023488_1973-4-14_2015.jpg
#   inflating: gender/train/0/61nm0000661_rm3380517632_1935-7-17_2005.jpg
#   inflating: gender/train/0/835788283_1974-03-06_2009.jpg
#   inflating: gender/train/0/82nm0001282_rm391496704_1960-5-20_2012.jpg
#   inflating: gender/train/0/78nm0719678_rm3411056640_1960-9-14_2001.jpg
#   inflating: gender/train/0/48nm0000148_rm4149058048_1942-7-13_2002.jpg
#   inflating: gender/train/0/59nm0121559_rm1957280512_1960-9-12_1993.jpg
#   inflating: gender/train/0/91nm0000591_rm2126427392_1933-8-18_1979.jpg
# ...

# %%
# Moving the face_weight.pth to face_data directory
# %mv /content/CPG/face_weight.pth /content/CPG/face_data/

# %%
# Moving the lfw_pairs.txt to face_data
# %mv /content/CPG/lfw_pairs.txt /content/CPG/face_data

# %%
# !rm -r /content/CPG/data/gender

# %%
# Moving the gender directory to data directory
# %mv /content/CPG/gender /content/CPG/data

# %%
# Fine-tunning
# !bash /content/CPG/experiment3/baseline_face.sh

# %%
# %cd ..

# %%
# !gdown --id 1a-FiCtYO_7nRcI9eIHrlZysq_0N3Sh2P

# %%
# !unzip /content/five_datasets.zip

# %%
# !bash /content/CPG/experiment3/FvGeEm_CPG_face.sh

# %%
# %cd CPG

# %%
# %cp -r /content/CPG/age2 /content/CPG/data/2/

# %%
# !cat experiment3/inference_FvGeEmAg.sh > inf_file.txt

# %%
# %cd ..
# %mkdir Output
# %cd /content/CPG

# %%
# %mkdir /content/img

# %%
# %cp /content/CPG/data/gender/val/0/im_GenFex_06179.jpg /content/img
# %rm -r /content/CPG/data/gender/val/0
# %cp /content/CPG/data/gender/val/1/im_GenFex_06185.jpg /content/img
# %rm -r /content/CPG/data/gender/val/1
# %cp /content/CPG/data/gender/val/2/im_GenFex_07341.jpg /content/img
# %rm -r /content/CPG/data/gender/val/2

# %%
# %mkdir /content/CPG/data/gender/val/0 /content/CPG/data/gender/val/1 /content/CPG/data/gender/val/2

# %%
# %mv /content/img/im_GenFex_07341.jpg /content/CPG/data/gender/val/2/
# %mv /content/img/im_GenFex_06179.jpg /content/CPG/data/gender/val/0/
# %mv /content/img/im_GenFex_06185.jpg /content/CPG/data/gender/val/1/

# %%
# !bash /content/CPG/experiment3/inference_FvGeEmAg.sh /content/Output/inf.txt
# Out:
# Streaming output truncated to the last 5000 lines.
# Val Ep. #0:  77% 2372/3086 [00:35<00:09, 76.91it/s, loss=1.1, accuracy=71.29, sparsity=1, task1 ratio=0, zero ratio=1, mpl=1]
# output-size:  torch.Size([1, 3])
#
# output:  tensor([[0., 0., 0.]], device='cuda:0')
#
#  num:  1
# target:  tensor([1], device='cuda:0')
# Val Ep. #0:  77% 2372/3086 [00:35<00:09, 76.91it/s, loss=1.1, accuracy=71.26, sparsity=1, task1 ratio=0, zero ratio=1, mpl=1]
# output-size:  torch.Size([1, 3])
#
# output:  tensor([[0., 0., 0.]], device='cuda:0')
#
#  num:  1
# target:  tensor([1], device='cuda:0')
# Val Ep. #0:  77% 2373/3086 [00:35<00:09, 76.91it/s, loss=1.1, accuracy=71.23, sparsity=1, task1 ratio=0, zero ratio=1, mpl=1]
# output-size:  torch.Size([1, 3])
#
# output:  tensor([[0., 0., 0.]], device='cuda:0')
#
#  num:  1
# target:  tensor([1], device='cuda:0')
# Val Ep. #0:  77% 2374/3086 [00:35<00:09, 76.91it/s, loss=1.1, accuracy=71.20, sparsity=1, task1 ratio=0, zero ratio=1, mpl=1]
# ...

# %%
# !ls -l /content/CPG/data/gender/val/2
# Out:
# total 284
# -rw-r--r-- 1 root root 6173 May  3  2019 im_GenFex_06301.jpg
# -rw-r--r-- 1 root root 6909 May  3  2019 im_GenFex_06486.jpg
# -rw-r--r-- 1 root root 5906 May  3  2019 im_GenFex_06556.jpg
# -rw-r--r-- 1 root root 5294 May  3  2019 im_GenFex_06804.jpg
# -rw-r--r-- 1 root root 5428 May  3  2019 im_GenFex_06811.jpg
# -rw-r--r-- 1 root root 9061 May  3  2019 im_GenFex_07202.jpg
# -rw-r--r-- 1 root root 3706 May  3  2019 im_GenFex_07210.jpg
# -rw-r--r-- 1 root root 6481 May  3  2019 im_GenFex_07341.jpg
# -rw-r--r-- 1 root root 4739 May  3  2019 im_GenFex_07389.jpg
# -rw-r--r-- 1 root root 9914 May  3  2019 im_GenFex_07392.jpg
# -rw-r--r-- 1 root root 5771 May  3  2019 im_GenFex_07414.jpg
# -rw-r--r-- 1 root root 7025 May  3  2019 im_GenFex_07505.jpg
# -rw-r--r-- 1 root root 5283 May  3  2019 im_GenFex_07558.jpg
# -rw-r--r-- 1 root root 8539 May  3  2019 im_GenFex_07634.jpg
# -rw-r--r-- 1 root root 5145 May  3  2019 im_GenFex_07793.jpg
# ...
